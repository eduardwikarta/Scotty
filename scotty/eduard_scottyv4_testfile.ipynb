# %%
import numpy as np

# %% [markdown]
# ### Testing q conversions

# %%
from scotty.hamiltonian_v4 import initialise_hamiltonians
from scotty.fun_general_v4 import find_q_labframe_cart_to_cyl, find_q_labframe_cyl_to_cart

def scottyv4_test_q_conversions(q_X, q_Y, q_Z):
    q_cart = q_X, q_Y, q_Z
    q_cyl = find_q_labframe_cart_to_cyl(q_cart)
    q_cart_new = find_q_labframe_cyl_to_cart(q_cyl)
    print(q_cart == q_cart_new)

scottyv4_test_q_conversions(q_X=np.random.random((1,)), q_Y=np.random.random((1,)), q_Z=np.random.random((1,)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scotty.hamiltonian_v4 import initialise_hamiltonians
#       2 from scotty.fun_general_v4 import find_q_labframe_cart_to_cyl, find_q_labframe_cyl_to_cart
#       3
#       4 def scottyv4_test_q_conversions(q_X, q_Y, q_Z):
#
# ModuleNotFoundError: No module named 'scotty.hamiltonian_v4'
